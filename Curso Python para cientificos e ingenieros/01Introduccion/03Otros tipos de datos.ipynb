# %%
lista_anidada = [[1,2], [3,4]]
lista_anidada
# Out:
# [[1, 2], [3, 4]]

# %%
lista_anidada = [
                [1,2],
                [3,4] 
                ]
lista_anidada
# Out:
# [[1, 2], [3, 4]]

# %%
lista_anidada[0]
# Out:
# [1, 2]

# %%
lista_anidada[0][0]
# Out:
# 1

# %%
lista_anidada[0][1]
# Out:
# 2
