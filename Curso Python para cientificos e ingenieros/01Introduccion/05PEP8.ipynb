# %% [markdown]
# # **PEP8, la guía de estilo**
#
#
#
# ---
#
#
#
# *   Usa sangrado de 4 espacios, no tabuladores [IPython o tu editor se encargan de ello)
# *   Acota las líneas a 79 caracteres
# *   Usa líneas en blanco para separar funciones y bloques de codigo dentro de ellas
# *   Pon los comentarios en lineas aparte si es posible
# *   Usa la convención minuscula_con_guiones_bajos para los nombres de las funciones y las variables.
# *   Aunque Python 3 lo permite, no uses caracteres especiales para los identificadores.

# %% [markdown]
# Instalar, actualizar y desinstalar PEP8
# 1.   pip install pep8
# 3.   pip install --upgrade pep8
# 2.   pip uninstall pep8

# %% [markdown]
# *Para mas información consultar los siguientes enlaces:*
#
# *   En COLAB y jupyter notebook, dejo de funcionar pep8, ahora funciona pycodestyle: https://stackoverrun.com/es/q/7167752
# *   En el siguiente enlace, puede encontrrear los codigos de error:
# https://pep8.readthedocs.io/en/release-1.7.x/intro.html#example-usage-and-output
# *   Ejemplos en Jupyter notebook :
# https://nbviewer.jupyter.org/github/SiggyF/notebooks/blob/master/styleguide.ipynb

# %%
pip install pycodestyle
# Out:
# ...
#      |████████████████████████████████| 51kB 2.3MB/s
# ...

# %%
pip install pycodestyle_magic

# %%
pip install flake8
# Out:
# ...
#      |████████████████████████████████| 81kB 2.2MB/s
# ...
#      |████████████████████████████████| 71kB 3.4MB/s
# ...

# %%
# %load_ext pycodestyle_magic

# %%
# %%pycodestyle
# a=1
# Out:
# 2:2: E225 missing whitespace around operator

# %%
# %%pycodestyle
#
# if 6*9==42: print("Errores comunes")
# Out:
# 3:7: E225 missing whitespace around operator
# 3:11: E701 multiple statements on one line (colon)
