# %% [markdown]
# # **Funcion plot**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# La función **`plot`** recibe un conjunto de valores x e y, y los muestra en el plano definido por los ejes como puntos unidos por líneas

# %%
x = [1, 2, 3, 4]
y = [2, 5, 1, 7]
plt.plot(x, y)
plt.show()

# %% [markdown]
# Si no se indica el argumento x, se asigna un conjunto de valores por defecto formado por números enteros desde 0 hasta n-1 (es decir toma las posiciones del vector y)

# %%
y = [2, 5, 1, 7]
plt.plot(x, y)
plt.show()

# %% [markdown]
# Es importante que ejecutemos la función **plt.show()** al final del código. Si no lo hacemos, el código devolverá el resultado en forma de texto (haciendo referencia al conjunto de líneas o bloques gráficos que se han generado), algo como:
#
# `[<matplotlib.lines.Line2D at 0x1bc78210588>]`

# %% [markdown]
# Hay ocasiones en las que, aunque no incluyamos la función plt.show() al final del código, se muestra la gráfica pero junto a una salida de texto semejante a la mostrada. Por ejemplo:

# %%
plt.plot([2, 5, 1, 7])

#Por ese motivo hay que añadir siempre la funcion show()

# %% [markdown]
# ## **Dos graficas en la misma figura.**
#
# Se puede conseguir, ejecutando dos veces la función plot. Ejemplo

# %%
plt.plot([2, 5, 1, 7])
plt.plot([1, 2, 3, 4])
plt.show()

#LOS COLORES DE LAS GRAFICAS SON DEFINIDOS DE FORMA AUTOMATICA, SI NO SE ESPECIFICAN

# %% [markdown]
# Que pasa si ejecutamos show(), despues de cada plot:

# %%
plt.plot([2, 5, 1, 7])
plt.show()
plt.plot([1, 2, 3, 4])
plt.show()
#Obtenemos una figura diferente, recordemos que plot crea una figura nueva cada vez que es ejecutado, 
#por ende pierde la referencia de  la primera figura.
