# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielMdevlop/PythonDataScience/blob/main/Pandas_Resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# La librería pandas (nombre derivado de **panel data**, término usado para referirse a conjuntos de *datos estructurados* multidimensionales) proporciona estructuras de datos y funciones de alto nivel que nos permiten trabajar con datos estructurados de manera muy cómoda. Estas estructuras y funciones son, normalmente, de las más usadas en análisis de datos

# %% [markdown]
# Forma convencional de importar la libreria PANDAS

# %%
import pandas as pd

# %% [markdown]
# Lecturas de archivos CSV. Hay que aclarar que hay diferentes tipos de archivos, los cuales Pandas tiene funciones para dar lectura a cada uno de ellos.
# Los formatos que Pandas admite son:
#
#
#
# *   CSV
# *   XLS
# *   HTML
# *   JSON
# *   SQL
# *   PARQUET
# *   ETC.

# %% [markdown]
# Los archivos se cargan o guardan en la esctructura de datos **DataFrame de Pandas**.
#
# ## **¿Qué es un DataFrame?**
#
# Una estructura tabular o tabla, se compone por filas y columnas, donde cada una de las columnas puede admitir diferentes tipos de datos, sin embargo, nunca habra dos tipos de datos en la misma columna.

# %% [markdown]
# Cada fila y cada columna tiene dos tipos de identificadores.
#
# *  Los indices posicionales ( son los secuenciales empezando por cero)
# *  Las etiquetas (normalmente son las columnas las que tienen etiqueta)

# %%
#Lectura de un archivo CSV

df = pd.read_csv("dataset.csv")
df
# Out:
#         id  ... followees
# 0   183721  ...       258
# 1   183722  ...      1822
# 2   183723  ...       129
# 3   183724  ...       378
# 4   183725  ...       129
# 5   183726  ...      1822
# 6   183727  ...       258
# 7   183728  ...       129
# 8   183729  ...       129
# 9   183730  ...      1822
# 10  183731  ...      1822
# 11  183732  ...      1822
# 12  183733  ...       258
# 13  183734  ...       258
# 14  183735  ...      2721
# 15  183736  ...       129
# 16  183737  ...       351
# 17  183738  ...      2721
# 18  183739  ...       378
# 19  183740  ...       351
# 20  183741  ...       378
# 21  183742  ...       378
# 22  183743  ...       351
# 23  183744  ...       351
# 24  183745  ...       351
# 25  183746  ...      2721
# 26  183747  ...      9918
#
# [27 rows x 9 columns]

# %% [markdown]
# Se le puede indicar a Pandas que no genere un identificador para la filas, es decir podemos indicarle con el argumento `index` que columna es la que representa el ID para nuestro dataset.

# %%
#Lectura de un archivo CSV, indicando cual sera nuestro ID

df = pd.read_csv("dataset.csv", index_col='id')
df

#Observamos que ahora los valores de la columna id son nuestros identificadores
#ya que estan en negritas.
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...        258
# 183722                Today we commemorate and MNML Case.  ...       1822
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!  ...       1822
# 183727                                 80's & friends! ✈️  ...        258
# 183728  Thank you guess how did I feel somewhat offend...  ...        129
# 183729        OnePlus 8 international giveaway classifies  ...        129
# 183730                Here it is.. Retweet this desperate  ...       1822
# 183731  Great to advertise during the year I tweeted a...  ...       1822
# ...

# %%
#con la funcion head(), podemos dar un vistaso a nuestro dataset, por defecto se 
#muestran 5 primeras filas, sin embargo con el argumento n, se le puede indicar
#el numero de filas a visualizar.
df.head(n=10)
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...        258
# 183722                Today we commemorate and MNML Case.  ...       1822
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!  ...       1822
# 183727                                 80's & friends! ✈️  ...        258
# 183728  Thank you guess how did I feel somewhat offend...  ...        129
# 183729        OnePlus 8 international giveaway classifies  ...        129
# 183730                Here it is.. Retweet this desperate  ...       1822
#
# [10 rows x 8 columns]

# %%
#Con la función tail() podremos visualizar las ultimas 5 filas de nuestros datos
df.tail()
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183743                         Amazing video by Leonardo!  ...        351
# 183744                                        Thanks man!  ...        351
# 183745          There is nothing better than programming!  ...        351
# 183746                                           BORED AF  ...       2721
# 183747  I do not know if i like programming or other t...  ...       9918
#
# [5 rows x 8 columns]

# %%
#Podemos obtener las dimenciones o forma del dataframe
df.shape

#en este caso 27 filas y 8 columnas
# Out:
# (27, 8)

# %% [markdown]
# ## **Inspección de los datos (exploración)**

# %% [markdown]
# El método `describe` devuelve *información estadística de los datos* del dataframe o de la serie (de hecho, este **método devuelve un dataframe**). Esta información incluye el **número de muestras, el valor medio, la desviación estándar, el valor mínimo, máximo, la mediana y los valores correspondientes a los percentiles 25% y 75%**

# %%
df.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   26.000000   26.000000  26.000000   26.000000    27.000000
# mean   280.538462   80.000000  15.423077  352.807692  1190.185185
# std    153.377242   40.303846   9.596554  375.319493  1965.735995
# min     23.000000   21.000000   1.000000   12.000000   129.000000
# 25%    139.250000   45.500000   8.250000   21.000000   258.000000
# 50%    305.500000   79.000000  16.000000  332.000000   351.000000
# 75%    422.500000  110.750000  23.500000  389.000000  1822.000000
# max    500.000000  146.000000  29.000000  982.000000  9918.000000

# %% [markdown]
# El método `info` muestra un **resumen** de un dataframe, incluyendo información sobre el tipo de **los índices de filas y columnas**, **los valores no nulos y la memoria usada**:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 183721 to 183747
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  27 non-null     object
#  1   favorites  26 non-null     float64
#  2   retweets   26 non-null     float64
#  3   mentions   26 non-null     float64
#  4   country    27 non-null     object
#  5   user       27 non-null     object
#  6   followers  26 non-null     float64
#  7   followees  27 non-null     int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
#Podemos obtener solo los tipos de datos con el atributo dtypes
df.dtypes
# Out:
# full_text     object
# favorites    float64
# retweets     float64
# mentions     float64
# country       object
# user          object
# followers    float64
# followees      int64
# dtype: object

# %% [markdown]
# ## **Limpieza de datos**

# %%
df.head()
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...        258
# 183722                Today we commemorate and MNML Case.  ...       1822
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
#
# [5 rows x 8 columns]

# %%
#Devolver un dataframe sin campos incompletos (N/A)
df_filtrado = df.dropna()

df_filtrado.head()
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!  ...       1822
# 183727                                 80's & friends! ✈️  ...        258
#
# [5 rows x 8 columns]

# %% [markdown]
# En el caso que no se quiera eliminar los campos vacios o nulos, estos se pueden
# rellenar con un valor indicado, se logra con el método *fillna()* pasando como argumento el valor que se pondra en los valores nulos.

# %%
#RELLANA LOS N/A en este caso con 0
df_filtrado = df.fillna(0)

df_filtrado.head()
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...        258
# 183722                Today we commemorate and MNML Case.  ...       1822
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
#
# [5 rows x 8 columns]

# %%
#Algo mas complicado seria rellenar cada fila y de acuerdo a la columna correspondiente con valores especificos

df.head()
# Out:
#                                                 full_text  ...  followees
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...        258
# 183722                Today we commemorate and MNML Case.  ...       1822
# 183723       Today we have reached US$6.55 Billion TT$44…  ...        129
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...        378
# 183725                                    Welcome back! 🙌  ...        129
#
# [5 rows x 8 columns]

# %%
#Lo anterior se logra pasando un diccionario donde se indiquen las columnas como llaves y los valores con el valor asociado
df  = df.fillna({"retweets" : 0, "mentions" : -1})

df.head()
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...     1.138554
# 183725                                    Welcome back! 🙌  ...    10.750000
#
# [5 rows x 10 columns]

# %% [markdown]
# ## **Filtro de datos**

# %% [markdown]
# Con Pandas se puede realizar filtraciones de los datos, algo muy similar con las sentencias o consultas SQL, aqui se pueden obtener subconjuntos de los datos
# ya sea por indexación, etc.

# %% [markdown]
# **Por columnas**

# %%
#Obtener los datos de la columna favoritos y asi sucesivamente.
df["favorites"]
# Out:
# id
# 183721     23.0
# 183722    500.0
# 183723    190.0
# 183724    131.0
# 183725    113.0
# 183726    492.0
# 183727    158.0
# 183728      NaN
# 183729    198.0
# 183730    272.0
# 183731     43.0
# 183732    349.0
# 183733    467.0
# 183734     50.0
# 183735    418.0
# 183736    361.0
# 183737    346.0
# 183738    296.0
# 183739    315.0
# 183740    133.0
# 183741     92.0
# 183742    255.0
# 183743    432.0
# 183744    430.0
# 183745    424.0
# 183746    488.0
# 183747    318.0
# Name: favorites, dtype: float64

# %%
#Obtener todas las filas de ciertas columnas, pasando una lista con los nombres de las columnas
df[["favorites", "full_text", "country"]]
# Out:
#         favorites                                          full_text  country
# id
# 183721       23.0  Flying home to run down from the power to comi...  ECUADOR
# 183722      500.0                Today we commemorate and MNML Case.   BRASIL
# 183723      190.0       Today we have reached US$6.55 Billion TT$44…   MEXICO
# 183724      131.0  Faking It by Joel Atwell. Written by Other cou...  ECUADOR
# 183725      113.0                                    Welcome back! 🙌   MEXICO
# 183726      492.0  Contest: Win a fan of his ass. #thatisall Thanks!   BRASIL
# 183727      158.0                                 80's & friends! ✈️  ECUADOR
# 183728        NaN  Thank you guess how did I feel somewhat offend...   MEXICO
# 183729      198.0        OnePlus 8 international giveaway classifies   MEXICO
# 183730      272.0                Here it is.. Retweet this desperate   BRASIL
# 183731       43.0  Great to advertise during the year I tweeted a...   BRASIL
# ...

# %% [markdown]
# **Por Filas**

# %%
#FILTRAR FILAS POR INDICES
df.iloc[[0, 1, 2]]
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
#
# [3 rows x 10 columns]

# %%
#filtrar filas por el ID
df.loc[[183721, 183722]]
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
#
# [2 rows x 10 columns]

# %% [markdown]
# **Por Filas y Columnas**

# %%
df.loc[ [183721, 183722] ,["country"]]
# Out:
#         country
# id
# 183721  ECUADOR
# 183722   BRASIL

# %%
#Filtrar por condiciones

df[df["favorites"] > 400]
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!  ...     1.855397
# 183733                           Programming is the best!  ...     0.663239
# 183735                             Buy this product NOW!!  ...   129.571429
# 183743                         Amazing video by Leonardo!  ...     4.280488
# 183744                                        Thanks man!  ...          NaN
# 183745          There is nothing better than programming!  ...     4.280488
# 183746                                           BORED AF  ...   129.571429
#
# [8 rows x 10 columns]

# %%
df[(df["favorites"] > 400) & (df["mentions"] > 20)]
# Out:
#                                         full_text  ...  popularidad
# id                                                 ...
# 183744                                Thanks man!  ...          NaN
# 183745  There is nothing better than programming!  ...     4.280488
# 183746                                   BORED AF  ...   129.571429
#
# [3 rows x 10 columns]

# %%
#Condiciones con cadenas de texto

df[df["full_text"].str.contains("Programming")]
# Out:
#                           full_text  favorites  ...  ganancias  popularidad
# id                                              ...
# 183733     Programming is the best!      467.0  ...      345.0     0.663239
# 183740  Programming is a hot topic!      133.0  ...      435.0     4.280488
# 183741      Programming? i love it!       92.0  ...      584.0     1.138554
#
# [3 rows x 10 columns]

# %% [markdown]
# ## **Transformación de Datos**

# %%
#Agregando columnas para transformar los datos, es decir agregar mas informacion para el dataset

#Primero se debe definir el proceso para agregar esa columna
import random
def calcularaGanancias(retweets):
    return retweets * random.randint(3, 5)

# %%
df["ganancias"] = df["retweets"].apply(calcularaGanancias)

df.head()
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...     1.138554
# 183725                                    Welcome back! 🙌  ...    10.750000
#
# [5 rows x 10 columns]

# %%
def popularidad(fila):
    return fila["followees"] / fila["followers"]

# %%
df["popularidad"] = df.apply(popularidad, axis=1)

df.head()
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...     1.138554
# 183725                                    Welcome back! 🙌  ...    10.750000
#
# [5 rows x 10 columns]

# %% [markdown]
# ## **Agrupar los datos**
#
# Se pueden agrugar por datos por medio de una categoria.
#
# Agrupar significa unir filas que tengan un mismo valor dentro de una columna. Pero ¿Que sucede con los valores de otras columnas que se se agrupan?
# Estos valores deben sufrir una transformación. Que puede ser por ejemplo, quedarnos con el promedio de todos los valores que se agrupan, o coger el valor máximo o el minimo o sumar todos los valores.
#
# Algo similar que se hace en estadistica con la tablas de frecuencia agrupadas.

# %%
#Agrupar el dataframe por la columna pais
df.head()
# Out:
#                                                 full_text  ...  popularidad
# id                                                         ...
# 183721  Flying home to run down from the power to comi...  ...     0.663239
# 183722                Today we commemorate and MNML Case.  ...     1.855397
# 183723       Today we have reached US$6.55 Billion TT$44…  ...    10.750000
# 183724  Faking It by Joel Atwell. Written by Other cou...  ...     1.138554
# 183725                                    Welcome back! 🙌  ...    10.750000
#
# [5 rows x 10 columns]

# %% [markdown]
# Se agrupa con el metodo `groupby`
# Ahora la columna country se ha puesto en negritas, esto quiere decir que dicha columna ha pasado a ser nuevo identificador de mi DataFrame

# %%
 
df.groupby("country").mean()

#Observamos que solo tenemos una fila por cada pais, y a todas la columnas se les ha aplicado una funcion promedio
# Out:
#           favorites   retweets   mentions  ...    followees   ganancias  popularidad
# country                                    ...
# BRASIL   339.909091  91.272727  17.727273  ...  1889.363636  372.090909     3.708644
# ECUADOR  186.375000  56.750000  11.875000  ...   318.000000  240.250000     0.900897
# MEXICO   294.857143  77.750000  13.750000  ...  1101.000000  321.375000    55.308036
#
# [3 rows x 7 columns]

# %%
#Aplicar diferentes funciones a cada columna de la agrupación:

grouped = df.groupby("country").agg({"followers" : 'sum', 
                           "mentions" : 'mean', 
                           "retweets" : 'max'
                          })

# %%
grouped[grouped["followers"] > 5000]
# Out:
#          followers   mentions  retweets
# country
# BRASIL      6166.0  17.727273     145.0

# %% [markdown]
# ## **Graficación de Datos**

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
c1 = np.random.rand(100)
grouped["followers"].plot(kind="bar", cmap=plt.cm.Greens_r)
plt.show()

# %%
df.plot(kind="scatter", x="favorites", y="retweets")
plt.show()

# %% [markdown]
# ## **Guardando Datos**

# %%
#SUPONGAMOS QUE QUEREMOS GUARDAR:
grouped.head()
# Out:
#          followers   mentions  retweets
# country
# BRASIL      6166.0  17.727273     145.0
# ECUADOR     2884.0  11.875000     146.0
# MEXICO       123.0  13.750000     130.0

# %%
#Para guardar nuestro DataFrame en un archivo CSV

grouped.to_csv("Salida.csv")
